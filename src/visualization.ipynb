# %% [markdown]
# # Oasis Live '25 – Data Visualization

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %%
import pandas as pd
from charts import (
    create_attendance_by_concert_chart
)

# %% [markdown]
# ### Read CSV

# %%
df = pd.read_csv("../data/oasis_live_25.csv")

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Attendance by Concert

# %%
create_attendance_by_concert_chart(df).show()
